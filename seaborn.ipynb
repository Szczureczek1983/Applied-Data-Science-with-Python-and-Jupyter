# %% [markdown]
# <a href="https://colab.research.google.com/github/Szczureczek1983/Applied-Data-Science-with-Python-and-Jupyter/blob/master/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
# %matplotlib inline
register_matplotlib_converters()

# %% [markdown]
# Pierwsze wykresy

# %%
fig, ax = plt.subplots()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig, ax = plt.subplots()
x = [0,1,2,3,4,5]
y = [1,2,3,4,5,6]
ax.plot(x,y)
plt.show()

# %%
fig, ax = plt.subplots()
x = [0,1,2,3,4,5]
y = [1,2,3,4,5,6]
ax.plot(x,y)
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(2,1)
plt.show()

# %% [markdown]
# Wykresy liniowe

# %%
# !git clone https://github.com/matzim95/ML-datasets.git
# Out:
# Cloning into 'ML-datasets'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 182 (delta 44), reused 59 (delta 12), pack-reused 0
# Receiving objects: 100% (182/182), 27.22 MiB | 18.04 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
weather = pd.read_csv('ML-datasets/weather.csv', parse_dates = True, index_col = 'date')

# %%
weather.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2012-01-01 to 2015-12-31
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   precipitation  1461 non-null   float64
#  1   temp_max       1461 non-null   float64
#  2   temp_min       1461 non-null   float64
#  3   wind           1461 non-null   float64
#  4   weather        1461 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 68.5+ KB

# %%
fig, ax=plt.subplots()
ax.plot(weather.index, weather['temp_max'])
ax.plot(weather.index, weather['temp_min'])
plt.show()

# %%
ves_usd = pd.read_csv('ML-datasets/ves-usd.csv',thousands= ',', parse_dates=True, index_col = 'Date')

# %%
ves_usd.head()
# Out:
#                 Rate ISO Code From ISO Code To
# Date
# 2019-03-01  3295.300           USD         VES
# 2019-03-03  3295.300           USD         VES
# 2019-03-04  3294.905           USD         VES
# 2019-03-05  3294.810           USD         VES
# 2019-03-06  3294.905           USD         VES

# %%
fig, ax=plt.subplots()
ax.plot(ves_usd.index, ves_usd['Rate'],marker = 'P', linestyle = ':', color = 'green' )
ax.set_xlabel('Date(year-month-day)') # etykieta osi x
ax.set_ylabel('Rate') # etykieta osi y
ax.set_title('Kurs walut')
ax.xaxis.set_tick_params(rotation = 45)
plt.show()

# %% [markdown]
# Markery i linie

# %%
fig, ax=plt.subplots()
ax.plot(weather.index[:20], weather['temp_max'][:20], marker = "o", linestyle = '--', color = 'b')
ax.plot(weather.index[:20], weather['temp_min'][:20], marker = 'v', linestyle = 'None', color = 'r')
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(weather.index[:20], weather['temp_max'][:20], marker = "*", linestyle = '--', color = 'pink')
ax.plot(weather.index[:20], weather['temp_min'][:20], marker = 'P', linestyle = ':', color = 'green')
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(weather.index[:20], weather['temp_max'][:20], marker = "*", linestyle = '--', color = 'red')
ax.plot(weather.index[:20], weather['temp_min'][:20], marker = 'P', linestyle = ':', color = 'green')
ax.set_xlabel('Date(year-month-day)') # etykieta osi x
ax.set_ylabel('Temperature[celsjus)') # etykieta osi y
ax.set_title('Temperature in January 2012')
ax.xaxis.set_tick_params(rotation = 45)
plt.show()

# %%
austin_weather = pd.read_csv('ML-datasets/austin_weather.csv', parse_dates=True, index_col = 'Date').head(30)

# %%
austin_weather.head()
# Out:
#             TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# Date
# 2013-12-21         74        60        45            67           49
# 2013-12-22         56        48        39            43           36
# 2013-12-23         58        45        32            31           27
# 2013-12-24         61        46        31            36           28
# 2013-12-25         58        50        41            44           40
#
#            DewPointLowF HumidityHighPercent HumidityAvgPercent  \
# Date
# 2013-12-21           43                  93                 75
# 2013-12-22           28                  93                 68
# 2013-12-23           23                  76                 52
# 2013-12-24           21                  89                 56
# 2013-12-25           36                  86                 71
#
#            HumidityLowPercent SeaLevelPressureHighInches  \
# Date
# 2013-12-21                 57                      29.86
# ...

# %%
austin_weather.columns
# Out:
# Index(['TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF', 'DewPointAvgF',
#        'DewPointLowF', 'HumidityHighPercent', 'HumidityAvgPercent',
#        'HumidityLowPercent', 'SeaLevelPressureHighInches',
#        'SeaLevelPressureAvgInches', 'SeaLevelPressureLowInches',
#        'VisibilityHighMiles', 'VisibilityAvgMiles', 'VisibilityLowMiles',
#        'WindHighMPH', 'WindAvgMPH', 'WindGustMPH', 'PrecipitationSumInches',
#        'Events'],
#       dtype='object')

# %%
austin_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 2013-12-21 to 2014-01-19
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   TempHighF                   30 non-null     int64
#  1   TempAvgF                    30 non-null     int64
#  2   TempLowF                    30 non-null     int64
#  3   DewPointHighF               30 non-null     object
#  4   DewPointAvgF                30 non-null     object
#  5   DewPointLowF                30 non-null     object
#  6   HumidityHighPercent         30 non-null     object
#  7   HumidityAvgPercent          30 non-null     object
#  8   HumidityLowPercent          30 non-null     object
#  9   SeaLevelPressureHighInches  30 non-null     object
#  10  SeaLevelPressureAvgInches   30 non-null     object
#  11  SeaLevelPressureLowInches   30 non-null     object
#  12  VisibilityHighMiles         30 non-null     object
# ...

# %%
fig, ax=plt.subplots()
ax.plot(austin_weather.index, austin_weather['TempAvgF'].astype(float), color = 'r')
ax.plot(austin_weather.index, austin_weather['TempHighF'].astype(float), color = 'r', linestyle = '--')
ax.plot(austin_weather.index, austin_weather['TempLowF'].astype(float), color = 'r', linestyle = ':')

ax.plot(austin_weather.index, austin_weather['DewPointAvgF'].astype(float), color = 'b')
ax.plot(austin_weather.index, austin_weather['DewPointHighF'].astype(float), color = 'b', linestyle = '--')
ax.plot(austin_weather.index, austin_weather['DewPointLowF'].astype(float), color = 'b', linestyle = ':')

ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
ax.set_title('Weather in Austin')
ax.xaxis.set_tick_params(rotation = 45)
plt.show()

# %%
fig, ax=plt.subplots(2,1, sharey = True)
ax[0].plot(austin_weather.index, austin_weather['TempAvgF'].astype(float), color = 'r')
ax[0].plot(austin_weather.index, austin_weather['TempHighF'].astype(float), color = 'r', linestyle = '--')
ax[0].plot(austin_weather.index, austin_weather['TempLowF'].astype(float), color = 'r', linestyle = ':')

ax[1].plot(austin_weather.index, austin_weather['DewPointAvgF'].astype(float), color = 'b')
ax[1].plot(austin_weather.index, austin_weather['DewPointHighF'].astype(float), color = 'b', linestyle = '--')
ax[1].plot(austin_weather.index, austin_weather['DewPointLowF'].astype(float), color = 'b', linestyle = ':')

ax[1].set_xlabel('Date')
ax[0].set_ylabel('Temperature')
ax[1].set_ylabel('Dew Point')
ax[0].set_title('Weather in Austin')
ax[0].set_xticklabels([])
ax[1].xaxis.set_tick_params(rotation = 45)
plt.show()

# %%
fig, ax=plt.subplots(3,1, sharey = True)
ax[0].plot(austin_weather.index, austin_weather['TempAvgF'].astype(float), color = 'r')
ax[0].plot(austin_weather.index, austin_weather['TempHighF'].astype(float), color = 'r', linestyle = '--')
ax[0].plot(austin_weather.index, austin_weather['TempLowF'].astype(float), color = 'r', linestyle = ':')

ax[1].plot(austin_weather.index, austin_weather['DewPointAvgF'].astype(float), color = 'b')
ax[1].plot(austin_weather.index, austin_weather['DewPointHighF'].astype(float), color = 'b', linestyle = '--')
ax[1].plot(austin_weather.index, austin_weather['DewPointLowF'].astype(float), color = 'b', linestyle = ':')

ax[2].plot(austin_weather.index, austin_weather['WindHighMPH'].astype(float), color = 'g')
ax[2].plot(austin_weather.index, austin_weather['WindAvgMPH'].astype(float), color = 'g', linestyle = '--')
ax[2].plot(austin_weather.index, austin_weather['WindGustMPH'].astype(float), color = 'g', linestyle = ':')

ax[2].set_xlabel('Date')
ax[0].set_ylabel('Temperature($^\circ$C)')
ax[1].set_ylabel('Dew Point')
ax[2].set_ylabel('Wind')
ax[0].set_title('Weather in Austin')
ax[0].set_xticklabels([])
ax[1].set_xticklabels([])
ax[2].xaxis.set_tick_params(rotation = 45)
plt.show()

# %%
fig, ax=plt.subplots(3,1)
ax[0].plot(austin_weather.index, austin_weather['TempAvgF'].astype(float), color = 'r')
ax[0].plot(austin_weather.index, austin_weather['TempHighF'].astype(float), color = 'r', linestyle = '--')
ax[0].plot(austin_weather.index, austin_weather['TempLowF'].astype(float), color = 'r', linestyle = ':')

ax[1].plot(austin_weather.index, austin_weather['DewPointAvgF'].astype(float), color = 'b')
ax[1].plot(austin_weather.index, austin_weather['DewPointHighF'].astype(float), color = 'b', linestyle = '--')
ax[1].plot(austin_weather.index, austin_weather['DewPointLowF'].astype(float), color = 'b', linestyle = ':')

ax[2].plot(austin_weather.index, austin_weather['WindHighMPH'].astype(float), color = 'g')
ax[2].plot(austin_weather.index, austin_weather['WindAvgMPH'].astype(float), color = 'g', linestyle = '--')
ax[2].plot(austin_weather.index, austin_weather['WindGustMPH'].astype(float), color = 'g', linestyle = ':')

ax[2].set_xlabel('Date')
ax[0].set_ylabel('Temperature($^\circ$C)')
ax[1].set_ylabel('Dew Point')
ax[2].set_ylabel('Wind')
ax[0].set_title('Weather in Austin')
ax[0].set_xticklabels([])
ax[1].set_xticklabels([])
ax[2].xaxis.set_tick_params(rotation = 45)
ax[0].set_ylim(0,100)
ax[1].set_ylim(0,100)
ax[2].set_ylim(0, 40)
ax[0].annotate('Something happened', xy = [pd.Timestamp("2014-01-06"),28],
               xytext = (pd.Timestamp('2014-01-09'),23),
               arrowprops={'arrowstyle': "->", "color": "gray"})
plt.show()

# %%
co2 = pd.read_csv('ML-datasets/co2.csv', parse_dates = True, index_col = 'Date')
co2.head()
# Out:
#             Decimal Date  Average  Interpolated   Trend  Number of Days
# Date
# 1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1958-04-01      1958.292   317.45        317.45  315.29              -1
# 1958-05-01      1958.375   317.50        317.50  314.71              -1
# 1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 1958-07-01      1958.542   315.86        315.86  314.98              -1

# %%
temp = pd.read_csv('ML-datasets/temperature.csv', parse_dates = True, index_col = "dt")
temp.index.names = ['Date']

# %%
temp.head()
# Out:
#             AverageTemperature  AverageTemperatureUncertainty     City  \
# Date
# 1849-01-01              26.704                          1.435  Abidjan
# 1849-02-01              27.434                          1.362  Abidjan
# 1849-03-01              28.101                          1.612  Abidjan
# 1849-04-01              26.140                          1.387  Abidjan
# 1849-05-01              25.427                          1.200  Abidjan
#
#                   Country Latitude Longitude
# Date
# 1849-01-01  Côte D'Ivoire    5.63N     3.23W
# 1849-02-01  Côte D'Ivoire    5.63N     3.23W
# 1849-03-01  Côte D'Ivoire    5.63N     3.23W
# 1849-04-01  Côte D'Ivoire    5.63N     3.23W
# 1849-05-01  Côte D'Ivoire    5.63N     3.23W

# %%
temp['City'].unique()
# Out:
# array(['Abidjan', 'Addis Abeba', 'Ahmadabad', 'Aleppo', 'Alexandria',
#        'Ankara', 'Baghdad', 'Bangalore', 'Bangkok', 'Belo Horizonte',
#        'Berlin', 'Bogotá', 'Bombay', 'Brasília', 'Cairo', 'Calcutta',
#        'Cali', 'Cape Town', 'Casablanca', 'Changchun', 'Chengdu',
#        'Chicago', 'Chongqing', 'Dakar', 'Dalian', 'Dar Es Salaam',
#        'Delhi', 'Dhaka', 'Durban', 'Faisalabad', 'Fortaleza', 'Gizeh',
#        'Guangzhou', 'Harare', 'Harbin', 'Ho Chi Minh City', 'Hyderabad',
#        'Ibadan', 'Istanbul', 'Izmir', 'Jaipur', 'Jakarta', 'Jiddah',
#        'Jinan', 'Kabul', 'Kano', 'Kanpur', 'Karachi', 'Kiev', 'Kinshasa',
#        'Lagos', 'Lahore', 'Lakhnau', 'Lima', 'London', 'Los Angeles',
#        'Luanda', 'Madras', 'Madrid', 'Manila', 'Mashhad', 'Melbourne',
#        'Mexico', 'Mogadishu', 'Montreal', 'Moscow', 'Nagoya', 'Nagpur',
#        'Nairobi', 'Nanjing', 'New Delhi', 'New York', 'Paris', 'Peking',
# ...

# %%
set(temp['City'])
# Out:
# {'Abidjan',
#  'Addis Abeba',
#  'Ahmadabad',
#  'Aleppo',
#  'Alexandria',
#  'Ankara',
#  'Baghdad',
#  'Bangalore',
#  'Bangkok',
#  'Belo Horizonte',
#  'Berlin',
#  'Bogotá',
#  'Bombay',
#  'Brasília',
#  'Cairo',
#  'Calcutta',
#  'Cali',
#  'Cape Town',
#  'Casablanca',
#  'Changchun',
#  'Chengdu',
#  'Chicago',
#  'Chongqing',
#  'Dakar',
#  'Dalian',
#  'Dar Es Salaam',
#  'Delhi',
#  'Dhaka',
#  'Durban',
#  'Faisalabad',
#  'Fortaleza',
#  'Gizeh',
#  'Guangzhou',
#  'Harare',
#  'Harbin',
#  'Ho Chi Minh City',
#  'Hyderabad',
#  'Ibadan',
#  'Istanbul',
#  'Izmir',
#  'Jaipur',
#  'Jakarta',
#  'Jiddah',
#  'Jinan',
#  'Kabul',
#  'Kano',
#  'Kanpur',
#  'Karachi',
#  'Kiev',
#  'Kinshasa',
#  'Lagos',
#  'Lahore',
#  'Lakhnau',
#  'Lima',
#  'London',
#  'Los Angeles',
#  'Luanda',
#  'Madras',
#  'Madrid',
#  'Manila',
#  'Mashhad',
#  'Melbourne',
#  'Mexico',
#  'Mogadishu',
#  'Montreal',
#  'Moscow',
#  'Nagoya',
#  'Nagpur',
#  'Nairobi',
#  'Nanjing',
# ...

# %%
bangkok=temp[temp['City'] == 'Bangkok']
bangkok.head()
# Out:
#             AverageTemperature  AverageTemperatureUncertainty     City  \
# Date
# 1816-03-01              27.426                          1.793  Bangkok
# 1816-04-01              28.349                          3.011  Bangkok
# 1816-05-01              28.781                          1.980  Bangkok
# 1816-06-01              27.197                          1.823  Bangkok
# 1816-07-01              25.728                          1.414  Bangkok
#
#              Country Latitude Longitude
# Date
# 1816-03-01  Thailand   13.66N    99.91E
# 1816-04-01  Thailand   13.66N    99.91E
# 1816-05-01  Thailand   13.66N    99.91E
# 1816-06-01  Thailand   13.66N    99.91E
# 1816-07-01  Thailand   13.66N    99.91E

# %%
bangkok2=temp.query('City=="Bangkok"')
bangkok2.head()
# Out:
#             AverageTemperature  AverageTemperatureUncertainty     City  \
# Date
# 1816-03-01              27.426                          1.793  Bangkok
# 1816-04-01              28.349                          3.011  Bangkok
# 1816-05-01              28.781                          1.980  Bangkok
# 1816-06-01              27.197                          1.823  Bangkok
# 1816-07-01              25.728                          1.414  Bangkok
#
#              Country Latitude Longitude
# Date
# 1816-03-01  Thailand   13.66N    99.91E
# 1816-04-01  Thailand   13.66N    99.91E
# 1816-05-01  Thailand   13.66N    99.91E
# 1816-06-01  Thailand   13.66N    99.91E
# 1816-07-01  Thailand   13.66N    99.91E

# %%
merged = pd.merge(co2, bangkok, how = 'inner', on = 'Date')

# %%
merged.head()
# Out:
#             Decimal Date  Average  Interpolated   Trend  Number of Days  \
# Date
# 1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1958-04-01      1958.292   317.45        317.45  315.29              -1
# 1958-05-01      1958.375   317.50        317.50  314.71              -1
# 1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 1958-07-01      1958.542   315.86        315.86  314.98              -1
#
#             AverageTemperature  AverageTemperatureUncertainty     City  \
# Date
# 1958-03-01              29.528                          0.268  Bangkok
# 1958-04-01              30.430                          0.243  Bangkok
# 1958-05-01              30.796                          0.423  Bangkok
# 1958-06-01              29.128                          0.316  Bangkok
# 1958-07-01              27.888                          0.337  Bangkok
#
#              Country Latitude Longitude
# Date
# 1958-03-01  Thailand   13.66N    99.91E
# ...

# %%
fig, ax=plt.subplots()
ax.plot(merged.index, merged['Interpolated'])
ax.plot(merged.index, merged['AverageTemperature'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2/Temperature')
plt.show()

# %%
fig, ax=plt.subplots(figsize = (9,6))
ax.plot(merged.index, merged['Interpolated'], color = 'b')
ax.set_xlabel('Time')
ax.set_ylabel('CO2', color = 'b')
ax.tick_params('y', colors = 'b')
ax2=ax.twinx()
ax2.plot(merged.index, merged['AverageTemperature'], color = 'r')
ax2.set_ylabel('Temperature', color = 'r')
ax2.tick_params('y', colors = 'r')

# %%
merged_sub=merged['2000':]
fig, ax=plt.subplots(figsize = (9,6))
ax.plot(merged_sub.index, merged_sub['Interpolated'], color = 'b')
ax.set_xlabel('Time')
ax.set_ylabel('CO2', color = 'b')
ax.tick_params('y', colors = 'b')
ax2=ax.twinx()
ax2.plot(merged_sub.index, merged_sub['AverageTemperature'], color = 'r')
ax2.set_ylabel('Temperature', color = 'r')
ax2.tick_params('y', colors = 'r')

# %%
def plot_timestories(axis, x, y, color_def, xlab, ylab):
  axis.plot(x,y, color = color_def)
  axis.set_xlabel(xlab)
  axis.set_ylabel(ylab)
  axis.tick_params('y', color=color_def)

# %%
fig, ax=plt.subplots(figsize = (9,6))
plot_timestories(ax, merged_sub.index, merged_sub['Interpolated'], 'b', 'Time', 'CO2')
ax2=ax.twinx()
plot_timestories(ax2, merged_sub.index, merged_sub['AverageTemperature'], 'r', 'Time', 'Temperature')

# %%
pop=pd.read_csv('ML-datasets/population.csv', index_col = "City")
pop.head()
# Out:
#               Country or Area  Year   Area         Sex    City type  \
# City
# Bialystok              Poland  2017  Total  Both Sexes  City proper
# Bielsko-Biala          Poland  2017  Total  Both Sexes  City proper
# Bydgoszcz              Poland  2017  Total  Both Sexes  City proper
# Bytom                  Poland  2017  Total  Both Sexes  City proper
# Chorzów                Poland  2017  Total  Both Sexes  City proper
#
#                       Record Type             Reliability  Source Year  \
# City
# Bialystok      Estimate - de jure  Final figure, complete         2018
# Bielsko-Biala  Estimate - de jure  Final figure, complete         2018
# Bydgoszcz      Estimate - de jure  Final figure, complete         2018
# Bytom          Estimate - de jure  Final figure, complete         2018
# Chorzów        Estimate - de jure  Final figure, complete         2018
#
#                 Value Value Footnotes
# City
# Bialystok      294362             1,2
# ...

# %%
set(pop['Sex'])
# Out:
# {'Both Sexes', 'Female', 'Male'}

# %%
groupby = pop.groupby('Sex')
both, female, male = [groupby.get_group(x) for x in groupby.groups]

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.bar(both.index, both['Value'])
ax.xaxis.set_tick_params(rotation = 90)
ax.set_ylabel('Population')
plt.show()

# %%
both2=both.sort_values('Value', ascending=False)
fig, ax=plt.subplots(figsize = (10,8))
ax.bar(both2.index, both2['Value'])
ax.xaxis.set_tick_params(rotation = 90)
ax.set_ylabel('Population')
plt.show()

# %%
both2=both.sort_values('Value', ascending=False).head(10)
fig, ax=plt.subplots(figsize = (10,8))
ax.bar(both2.index, both2['Value'])
ax.xaxis.set_tick_params(rotation = 90)
ax.set_ylabel('Population')
plt.show()

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.bar(male.index, male["Value"],label = 'Male')
ax.bar(female.index, female['Value'], bottom = male['Value'], label = 'Female')
ax.xaxis.set_tick_params(rotation = 90)
ax.set_ylabel('Population')
ax.legend()
plt.show()

# %%
medals = pd.read_csv('ML-datasets/olympic.csv', index_col = "Year")

# %%
medals.head()
# Out:
#       ID                      Name Sex   Age  Height  Weight            Team  \
# Year
# 1992   1                 A Dijiang   M  24.0   180.0    80.0           China
# 2012   2                  A Lamusi   M  23.0   170.0    60.0           China
# 1920   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 1900   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1988   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#       NOC        Games  Season       City          Sport  \
# Year
# 1992  CHN  1992 Summer  Summer  Barcelona     Basketball
# 2012  CHN  2012 Summer  Summer     London           Judo
# 1920  DEN  1920 Summer  Summer  Antwerpen       Football
# 1900  DEN  1900 Summer  Summer      Paris     Tug-Of-War
# 1988  NED  1988 Winter  Winter    Calgary  Speed Skating
#
#                                  Event Medal
# Year
# 1992       Basketball Men's Basketball   NaN
# 2012      Judo Men's Extra-Lightweight   NaN
# ...

# %%
set(medals['Sport'])
# Out:
# {'Aeronautics',
#  'Alpine Skiing',
#  'Alpinism',
#  'Archery',
#  'Art Competitions',
#  'Athletics',
#  'Badminton',
#  'Baseball',
#  'Basketball',
#  'Basque Pelota',
#  'Beach Volleyball',
#  'Biathlon',
#  'Bobsleigh',
#  'Boxing',
#  'Canoeing',
#  'Cricket',
#  'Croquet',
#  'Cross Country Skiing',
#  'Curling',
#  'Cycling',
#  'Diving',
#  'Equestrianism',
#  'Fencing',
#  'Figure Skating',
#  'Football',
#  'Freestyle Skiing',
#  'Golf',
#  'Gymnastics',
#  'Handball',
#  'Hockey',
#  'Ice Hockey',
#  'Jeu De Paume',
#  'Judo',
#  'Lacrosse',
#  'Luge',
#  'Military Ski Patrol',
#  'Modern Pentathlon',
#  'Motorboating',
#  'Nordic Combined',
#  'Polo',
#  'Racquets',
#  'Rhythmic Gymnastics',
#  'Roque',
#  'Rowing',
#  'Rugby',
#  'Rugby Sevens',
#  'Sailing',
#  'Shooting',
#  'Short Track Speed Skating',
#  'Skeleton',
#  'Ski Jumping',
#  'Snowboarding',
#  'Softball',
#  'Speed Skating',
#  'Swimming',
#  'Synchronized Swimming',
#  'Table Tennis',
#  'Taekwondo',
# ...

# %%
def groupby_column(dataframe, column):
  groupby = dataframe.groupby(column)
  return {x: groupby.get_group(x) for x in groupby.groups}

# %%
all_sports = groupby_column(medals, 'Sport')

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.bar("Football", all_sports['Football']['Height'].mean(), yerr =all_sports['Football']['Height'].std() )
ax.bar("Basketball",all_sports['Basketball']['Height'].mean(), yerr =all_sports['Basketball']['Height'].std())
ax.set_ylabel('Height [cm]', fontsize = 12)
ax.set_title('Wzrost zawodników', fontsize = 18)
plt.show()

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.hist(all_sports['Football']['Height'], label = "Football", bins = 30)
ax.hist(all_sports['Basketball']['Height'], label = "Basketball", bins = 30, histtype = 'step')
ax.set_xlabel('Height [cm')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.hist(all_sports['Football']['Height'], label = "Football", bins =50)
ax.hist(all_sports['Basketball']['Height'], label = "Basketball", bins = 50, histtype = 'step')
ax.set_xlabel('Height [cm')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.hist(all_sports['Judo']['Weight'], label = "Judo", bins =50)
ax.hist(all_sports['Boxing']['Weight'], label = "Boxing", bins = 50, histtype = 'step')
ax.set_xlabel('weight [kg]')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.boxplot([all_sports['Football']['Height'].dropna(), all_sports['Basketball']['Height'].dropna()])
ax.set_xticklabels(['Football', 'Basketball'])
ax.set_ylabel('Height [cm]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.boxplot([all_sports['Judo']['Weight'].dropna(), all_sports['Boxing']['Weight'].dropna()])
ax.set_xticklabels(['Judo', 'Boxing'])
ax.set_ylabel('Weight [kg]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
fig, ax=plt.subplots(figsize = (10,8))
ax.scatter(merged['Interpolated'], merged['AverageTemperature'])
ax.set_xlabel('CO2')
ax.set_ylabel('Temperature')
plt.show()

# %%
eighties = merged['1980':'1989']
nineties = merged['1990':'1999']
millenium = merged['2000':'2009']
fig, ax=plt.subplots(figsize = (10,8))
ax.scatter(eighties['Interpolated'], eighties['AverageTemperature'], color = 'red', label = "80's")
ax.scatter(nineties['Interpolated'], nineties['AverageTemperature'], color = 'green', label = "90's")
ax.scatter(millenium['Interpolated'], millenium['AverageTemperature'], color = 'blue', label = "00's")
ax.set_xlabel('CO2')
ax.set_ylabel('Temperature')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.scatter(merged["Interpolated"], merged["AverageTemperature"],
           c=merged.index)  # zakodowanie czasu jako kolor (ciemny najwcześniej, żółty najpóźniej)
ax.set_xlabel('CO2')
ax.set_ylabel('Temperature')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.scatter(medals['Weight'], medals['Height'],
           c=medals['Age'])
ax.set_xlabel('Weight')
ax.set_ylabel('Height')
ax.grid()
plt.show()

# %% [markdown]
# Seaborn 09/04/2022

# %%
import seaborn as sns

# %%
wine = pd.read_csv("ML-datasets/wine.csv")

# %%
wine.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline Class
# ...

# %%
sns.lmplot(x="Alcohol", y= "Magnesium", data=wine)

# %%
sns.lmplot(x = 'Alcohol', y = 'Magnesium', data = wine, fit_reg=False, hue = 'Class')
plt.ylim(40, 140)
plt.xlim(10,20)
plt.xlabel('Zawartość alkoholu')
plt.ylabel('Zawartość magnezu')
plt.title('Obrazek 1', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Obrazek 1')

# %%
sns.scatterplot(x = 'Alcohol', y = 'Magnesium', data = wine, hue = 'Class')

# %%
sns.lmplot(x = 'Flavanoids', y = 'Color intensity', data = wine, fit_reg=False, hue = 'Class')
sns.set_style("white")
plt.xlabel('Zawartość flawonoidów', fontsize = 14)
plt.ylabel('Intensywność koloru', fontsize=14)
plt.title('Obrazek 2', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Obrazek 2')

# %%
sns.set_style("white")
g=sns.boxplot(data=wine.iloc[:,5:-2])
g.xaxis.set_tick_params(rotation = 45)

sns.set(rc = {'figure.figsize':(12,8)})

# %%
sns.set_style('whitegrid')
sns.violinplot(x = 'Class', y='Alcohol', data = wine)

# %%
sns.swarmplot(x='Class', y='Alcohol', data=wine)

# %%
sns.stripplot(x='Class', y='Alcohol', data=wine)

# %%
sns.stripplot(x='Alcohol', y='Class', data=wine)

# %%
sns.violinplot(x='Class', y='Alcohol', data = wine, inner = None)
sns.swarmplot(x='Class', y='Alcohol', data = wine, color = 'k', alpha = 0.9)
plt.title('Zawartość alkoholu w zależności od typu wina', fontsize = 20)
plt.xlabel('Klasa wina', fontsize = 20 )
plt.ylabel('Zawartość Alkoholu', fontsize = 20)
# Out:
# Text(0, 0.5, 'Zawartość Alkoholu')

# %%
sns.violinplot(x='Class', y='Malic acid', data = wine, inner = None)
sns.swarmplot(x='Class', y='Malic acid', data = wine, color = 'k', alpha = 0.9)
plt.title('Zawartość kwasu maleinowego w zależności od typu wina', fontsize = 20)
plt.xlabel('Klasa wina', fontsize = 20 )
plt.ylabel('Zawartość kwasu maleinowego', fontsize = 20)
# Out:
# Text(0, 0.5, 'Zawartość kwasu maleinowego')

# %%
sns.distplot(wine.Alcohol)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(wine.Alcohol, kde = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(wine.Alcohol, kde = True, hist = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x='Class', data=wine)

# %% [markdown]
# Liczymy korelacje

# %%
corr=wine.corr()

# %%
sns.heatmap(corr)

# %% [markdown]
# Rozkład gęstości

# %%
sns.kdeplot(x='Alcohol', y='Magnesium', data=wine)

# %%
sns.jointplot(x='Alcohol', y='Magnesium', data = wine)

# %%
wine.describe()
# Out:
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
wine['alcohol_power']=pd.cut(wine.Alcohol, bins = [0,12,13,15], labels=['low', 'middle', 'strong'] )

# %%
wine.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline Class alcohol_power
# ...

# %%
sns.barplot(x='Class', y='Magnesium', data=wine, hue='alcohol_power', palette=sns.color_palette("rocket"))
plt.legend(bbox_to_anchor=(1,1), loc = 2)

# %%
colors=['#FF0B04', '#4374B3']
moja_paleta = sns.set_palette(colors)

# %%
sns.barplot(x='Class', y='Magnesium', data=wine, hue='alcohol_power', palette=moja_paleta)
plt.legend(bbox_to_anchor=(1,1), loc = 2)

# %%
sns.histplot(x='Class', data=wine, hue='alcohol_power', weights='Magnesium', multiple='stack', palette = 'mako', shrink=0.8)

# %%
import plotly
import plotly.graph_objects as go
from plotly.offline import iplot

# %%
timedata = pd.read_csv('/content/ML-datasets/timesData.csv')

# %%
timedata.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
df = timedata.iloc[:100,:]

# %%
trace1=go.Scatter(x=df.world_rank,
                  y=df.citations,
                  mode='lines',
                  name = 'cytowania',
                  marker=dict(color = 'rgba(16,112,2,0.8)'),
                  text=df.university_name)
trace2=go.Scatter(x=df.world_rank,
                  y=df.teaching,
                  mode='lines+markers',
                  name = 'Poziom nauki',
                  marker = dict(color='rgba(80,26,80,0.8)'),
                  text=df.university_name)
data=[trace1,trace2]
layout=dict(title='Poziom nauczania i cytowania, a pozycja w rankingu TOP 100',
            xaxis=dict(title='Ranking światoey'))
fig = dict(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2014=timedata[timedata.year==2014].iloc[:100,:]
df2015=timedata[timedata.year==2015].iloc[:100,:]
df2016=timedata[timedata.year==2016].iloc[:100,:]

# %%
#wykres 1
trace1 = go.Scatter(x=df2014.world_rank,
                    y=df2014.citations,
                    mode='markers',
                    name = '2014',
                    marker=dict(color='rgba(200,128,128,0.8)'),
                    text = df2014.university_name)
trace2 = go.Scatter(x=df2015.world_rank,
                    y=df2015.citations,
                    mode='markers',
                    name = '2015',
                    marker=dict(color='rgba(255,128,2,0.8)'),
                    text = df2015.university_name)
trace3 = go.Scatter(x=df2016.world_rank,
                    y=df2016.citations,
                    mode='markers',
                    name = '2016',
                    marker=dict(color='rgba(255,128,200,0.8)'),                    
                    text = df2016.university_name)
data=[trace1,trace2,trace3]
layout=dict(title='Cytowania i ranking najlepszych uczelni w latach 2014-2016',
            xaxis=dict(title='Ranking'),
            yaxis=dict(title='Cytowania'))
fig=dict(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2014_new=timedata[timedata['year']==2014].iloc[:3,:]

# %%
trace1=go.Bar(
    x=df2014_new.university_name,
    y=df2014_new.citations,
    name='Cytowania',
    marker=dict(color='rgba(255,174,255,0.5)', line=dict(color='rgb(0,0,0)', width=1.5)),
    text=df2014_new.country
)
trace2=go.Bar(
    x=df2014_new.university_name,
    y=df2014_new.teaching,
    name='Nauczanie',
    marker=dict(color='rgba(255,255,128,0.5)', line=dict(color='rgb(0,0,0)', width=1.5)),
    text=df2014_new.country
)
data=[trace1, trace2]
layout=go.Layout(barmode='group')
fig=go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2016_new = timedata[timedata.year==2016].iloc[:7,:]

# %%
pie1=df2016_new.num_students
pie1_list=[float(each.replace(',','.')) for each in df2016_new.num_students]
labels=df2016_new.university_name
#wykres
fig={
    'data':[
            {
              "values":pie1_list,
             "labels":labels,
             "domain":{"x":[0,.5]},
             "name":"Liczba studentów",
             "hoverinfo":"label+percent+name",
             "hole":.3,
             "type":"pie"
            },
    ],
     'layout':{
         "title":"Procentowa liczba studentów na uniwersytetach",
         "annotations":[{
             "font":{"size":20},
             "showarrow":False,
             "text":"liczba studentów",
             "x":0.2,
             "y":1
         },]
     }
}
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2015_new = timedata[timedata.year==2015].iloc[:7,:]

# %%
pie2=df2015_new.num_students
pie2_list=[float(each.replace(',','.')) for each in df2015_new.num_students]
labels=df2015_new.university_name
#wykres
fig={
    'data':[
            {
              "values":pie1_list,
             "labels":labels,
             "domain":{"x":[0,.5]},
             "name":"Liczba studentów",
             "hoverinfo":"label+percent+name",
             "hole":.3,
             "type":"pie"
            },
    ],
     'layout':{
         "title":"Procentowa liczba studentów na uniwersytetach",
         "annotations":[{
             "font":{"size":20},
             "showarrow":False,
             "text":"liczba studentów",
             "x":0.2,
             "y":1
         },]
     }
}
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Wykresy 3D

# %%
trace1=go.Scatter3d(x=timedata['world_rank'],
                    y=timedata['research'],
                    z=timedata['citations'],
                    mode='markers',
                    marker=dict(size=5,
                                color='red'))
data=[trace1]
layout=go.Layout(margin=dict(
    l=0,
    r=0,
    b=0,
    t=0
))
fig=go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
trace1=go.Scatter3d(x=timedata['world_rank'],
                    y=timedata['female_male_ratio'],
                    z=timedata['citations'],
                    mode='markers',
                    marker=dict(size=5,
                                color='blue'))
data=[trace1]
layout=go.Layout(margin=dict(
    l=0,
    r=0,
    b=0,
    t=0
))
fig=go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# %%
px.line(data_frame=timedata.iloc[:100, :],
        x='world_rank', y='citations')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
mean_country=timedata.groupby('country',as_index=False).mean()

# %%
mean_country.head()
# Out:
#       country   teaching   research  citations  student_staff_ratio  \
# 0   Argentina  16.000000   9.000000  12.500000            38.100000
# 1   Australia  31.852137  36.118803  55.988889            27.294017
# 2     Austria  30.535484  23.535484  57.180645            24.480645
# 3  Bangladesh  21.700000   7.200000   9.600000             6.900000
# 4     Belarus  20.200000   8.700000   6.000000            10.600000
#
#           year
# 0  2016.000000
# 1  2014.000000
# 2  2013.903226
# 3  2016.000000
# 4  2016.000000

# %%
top10=mean_country.iloc[:10,:]

# %%
px.bar(data_frame=top10, x='country', y='teaching')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(data_frame=timedata, x='research', nbins=100)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotnine import *
from plotnine.data import mpg

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    category
#  1   model         234 non-null    category
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    category
#  6   drv           234 non-null    category
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    category
#  10  class         234 non-null    category
# dtypes: category(6), float64(1), int64(4)
# memory usage: 13.7 KB

# %%
(ggplot(mpg)+ aes(x='class')+
 geom_bar(size=20))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8740211599153)>

# %%
(ggplot(mpg)+aes(x='class')+
 geom_bar(size=20)+
 coord_flip()+
 labs(title='Liczba samochodów', x='Kategoria pojazdów', y='Liczba pojazdów'))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8740211552761)>

# %%
(ggplot(mpg)+
 aes(x='displ', y='hwy', color = 'class')+
 geom_point()+
 labs(title ='Pojemność silników a złużycie paliwa', x='Pojemność silnika', y="Liczba przejechanych mil na godzinę"))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8740211462265)>

# %%
(ggplot(mpg)+
 aes(x='displ', y='hwy', color = 'class')+
 geom_line()+
 labs(title ='Pojemność silników a złużycie paliwa', x='Pojemność silnika', y="Liczba przejechanych mil na godzinę"))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8740211415593)>

# %%
(ggplot(mpg)+
 aes(x='manufacturer', y='displ', color = 'class')+
 geom_point()+
 labs(title ='Pojemność silników a złużycie paliwa', x='Pojemność silnika', y="Liczba przejechanych mil na godzinę"))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8740211306809)>
